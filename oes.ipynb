# %%
import pandas as pd
from numpy import log as ln
from numpy import nan
from statsmodels.formula.api import ols
import os
import glob
from numpy import sqrt
from msilib.schema import Error
pd.options.mode.chained_assignment = None
source = os.path.abspath(os.getcwd())

# %%
class oes():

    def import_crsp(path,low_memory_=True):
        """Input path for a CRSP or Ivolatility file. This function will read the csv and drop 'Unnamed: 0' column. Rename 'date' to 'DataDate' and convert the data to datetime format."""
        df = pd.read_csv(path,low_memory=low_memory_)
        
        if 'Unnamed: 0' in df.columns:
            df = df.drop(columns= 'Unnamed: 0')
        
        if 'date' in df.columns:
            df = df.rename(columns= {"date":"DataDate"})

        df.DataDate = pd.to_datetime(df.DataDate)

        return df

    def import_ivol(ticker,folder):
        old = pd.DataFrame()
        paths = glob.glob(f"{folder}{ticker}_*.csv")
        if len(paths) != 0:
            for path in paths:
                df = oes.import_crsp(path)
                old = pd.concat([old,df])
            old.sort_values("DataDate")[['UnderlyingSymbol', 'UnderlyingPrice', 'Type', 'Expiration', 'DataDate','Strike', 'Bid', 'Ask', 'Volume', 'OpenInterest']]
            return(old)
        else:
            return(pd.DataFrame())

    def dupe_check(df_crsp,path_crsp):
        """This check looks for duplicate dates in the CRSP file. If in case the number of duplicate dates is more than 8 days in an year (ie 3%), then the check will open the corresponding csv file for CRSP and IVOL database.
        Note: Do not forget to check for different ivol files in case of multiple shareclass. """
        dupes = df_crsp[df_crsp.DataDate.duplicated(keep=False)]
        if len(dupes) == 0:
            return df_crsp
        
        # if dupes.DIVAMT.isnull().values.any():
        if len(dupes) > len(df_crsp)*0.03:
            print("dupe")
            os.startfile(path_crsp)
            input("Press enter to continue...")
            corrected_df = oes.import_crsp(path_crsp)
        
        else:
            corrected_df = df_crsp.groupby('DataDate').last()
            divamt = df_crsp.groupby('DataDate').sum().DIVAMT
            corrected_df.DIVAMT = divamt
            corrected_df = corrected_df.reset_index()
        
        return(corrected_df)

    def return_check(df,path):
        df = df.sort_values(by="DataDate")
        df = df.reset_index(drop=True)
        if df['RET'].iloc[0] == "C":
            df.loc[0,'RET'] = nan
        if "C" in df.RET.tolist():
            print("Ret")
            os.startfile(path)
            input("Press enter to continue...")
            df = oes.import_crsp(path)
        return(df)

    def regression(df, dtype):
        data_type = dtype + "LogRet"                                                #Adding a suffix to signify Log Returns 
        formula = data_type + " ~  Mkt_Lnrtn"                                       #Creating the formula for Regression
        years = df.index.year.unique().tolist()                                     #Creating a list of years for yearly regression

        if 2012 in years:
            years.remove(2012)

        df_reg = pd.DataFrame()                                                     #Empty df to concat yearly data to 

        for y in years:                                                             #Running a for loop for yearly regressions
            df_year = df.loc[f"{y}"]                                                #Filtering for a specific year
            try:
                if len(df_year.dropna(subset="SynthLogRet")) < 250:                 #Removing incomplete years 
                    continue
            except:
                if len(df_year.dropna(subset="CompanyLogRet")) < 250:               #Removing incomplete years 
                    continue
            fitted = ols(formula, data = df_year).fit()                             #Running the regression on the filtered year  
            explained_rtn = fitted.predict(exog = df_year)                          #Calculating the expected returns 
            df_year.loc[:,"ExplainedReturn"] = explained_rtn                        #Assigned a column to the expected returns 
            df_year.loc[:,"ResRtn"] = df_year[data_type] - explained_rtn            #Calculating Residual Returns
            df_year.loc[:,"Tstat"] = df_year.ResRtn/sqrt(fitted.scale)              #Calculating Tstat
            df_year.loc[:,"Sig"] = abs(df_year.Tstat) > 1.96                        #Checking significance
            df_year.loc[:,f"StdErr_{dtype}"] = fitted.bse[0]
            df_reg = pd.concat([df_reg,df_year])                                    #Joining the yearly regressions  
        if len(df_reg) == 0:
            return("Lack of data")
        return(df_reg)

    def blr(blr_path):
        df = pd.read_excel(blr_path, skiprows = 5).drop(columns = ["Date","PX_LAST.1","PX_LAST","Unnamed: 2"]).rename(columns={"Date.1":"DataDate","rate":"blr"})
        return(df)

    def fred(fred_path):
        df = pd.read_excel(fred_path,skiprows=10).rename(columns={"observation_date":"DataDate","DGS1":"fred"})
        df.fred = df.fred/100
        df = df.fillna(method="ffill")
        return(df)

    def marketdata(path):
        df = oes.import_crsp(path)
        df.loc[:,"Mkt_Lnrtn"] = ln(1 + df.vwretd)
        market = df[["DataDate","Mkt_Lnrtn"]].groupby("DataDate").mean()
        market.sort_index(inplace= True)
        return(market)

    def synthetic_stock(syn_df,cfacpr,fred,blr,volume_filter,oi_filter,zero_price_filter):

        if volume_filter == True:   
            syn_df = syn_df[syn_df.Volume != 0]                                     #Filtering for volume if volume_filter is True
        
        if oi_filter == True:
            syn_df = syn_df[syn_df.OpenInterest != 0]                               #Filtering for open interest if oi_filter is True

        syn_df.DataDate = pd.to_datetime(syn_df.DataDate)                           #Converting dates from str to datetime
        syn_df.Expiration = pd.to_datetime(syn_df.Expiration)                       #Converting dates from str to datetime

        syn_df = syn_df.merge(fred, on = 'DataDate', how = "left")                  #Joining fred data with df
        syn_df = syn_df.merge(blr, on = 'DataDate', how = "left")                   #Joining blr data with df
        
        syn_df.loc[:,"Tau"] = (syn_df.Expiration - syn_df.DataDate).dt.days         #Calculating Tau
        syn_df.loc[:,"YearFrac"] =  syn_df.Tau/365                                  #Converting Tau into years

        syn_df.loc[:,"BuyDiscount"] = ((1 + syn_df.fred) ** syn_df.YearFrac)        #Calculating Buy Discount
        syn_df.loc[:,"SellDiscount"] = (1 + syn_df.blr) ** syn_df.YearFrac          #Calculating Sell Discount
        
        syn_df.loc[:,"Spread"] = abs(syn_df.Ask - syn_df.Bid)
        syn_df.loc[:,"SpreadPercentage"] = syn_df.Spread/((syn_df.Bid+syn_df.Ask)/2)
        syn_df = syn_df[syn_df.SpreadPercentage < 1]

        call = syn_df[syn_df.Type == "call"].drop(columns = "Type")                 #Splitting the df into calls and puts
        call = call.rename(columns={'Last':'CallLast', 'Bid': "CallBid",\
            'Ask':"CallAsk", 'Volume':"CallVolume", 'OpenInterest':\
                'CallOpenInterest', 'IV':"CallIV", 'Delta':'CallDelta',\
                    'Gamma':'CallGamma', 'Theta':'CallTheta', 'Vega':'CallVega'})   #Renaming the columns
        
        put = syn_df[syn_df.Type == "put"].drop(columns = "Type")                   #Splitting the df into calls and puts
        put = put.rename(columns={'Last':'PutLast', 'Bid': "PutBid", \
            'Ask':"PutAsk", 'Volume':"PutVolume", 'OpenInterest':\
                'PutOpenInterest', 'IV':"PutIV", 'Delta':'PutDelta',\
                    'Gamma':'PutGamma', 'Theta':'PutTheta', 'Vega':'PutVega'})      #Renaming the columns
        
        syn_df = call.merge(put,how = "left", on=["Expiration","DataDate",\
            "Strike", "UnderlyingSymbol","UnderlyingPrice","BuyDiscount",\
                "SellDiscount","YearFrac","Tau","blr","fred"])                      #Merging the call and put df to make them parallel

        if zero_price_filter == True:                                               #Filtering for zero price quotes if zero_price_filter is True 
            syn_df = syn_df[syn_df["CallBid"] != 0]
            syn_df = syn_df[syn_df["PutBid"] != 0]
            syn_df = syn_df[syn_df["CallAsk"] != 0]
            syn_df = syn_df[syn_df["PutAsk"] != 0]

        syn_df = syn_df[syn_df["CallBid"] != 9999]
        syn_df = syn_df[syn_df["PutBid"] != 9999]
        syn_df = syn_df[syn_df["CallAsk"] != 9999]
        syn_df = syn_df[syn_df["PutAsk"] != 9999]

        abs(syn_df.CallAsk - syn_df.PutBid)/syn_df.CallAsk 

        syn_df.loc[:,"Buy"] = syn_df.Strike/syn_df.BuyDiscount                      #Calculating Buy price for the bond
        
        syn_df.loc[:,"Sell"] = syn_df.Strike/syn_df.SellDiscount                    #Calculating Sell price for the bond
        
        syn_df.loc[:,"SynthAsk"] = syn_df.CallAsk - \
            syn_df.PutBid + syn_df.Buy                                              #Calculating Synthetic stock's ask price
        
        syn_df.loc[:,"SynthBid"] = syn_df.CallBid - \
            syn_df.PutAsk + syn_df.Sell                                             #Calculating Synthetic stock's sell price
        
        syn_df.loc[:,"SynthPrice"] = (syn_df.SynthAsk + syn_df.SynthBid)/2          #Calculating Synthetic stock's price for the specific strike price on a day

        syn_df = syn_df.groupby("DataDate").mean()                                  #Calculating Synthetic stock's price on a day
        
        syn_df = syn_df.merge(cfacpr,on='DataDate',how='left')
        
        return(syn_df)

    def summarize(mkt_crsp,mkt_ivol,tic,filt):
        global com_after_cleaning,syn_after_cleaning,com_after_regression,syn_after_regression,summary_count
        mkt_crsp.loc[:,"CompanyLogRet"] = ln(mkt_crsp.RET.astype(float) + 1)
        mkt_ivol.loc[:,"SynthLogRet"] = ln(((mkt_ivol.SynthPrice*(mkt_ivol.CFACPR.shift(1)/mkt_ivol.CFACPR))/mkt_ivol.SynthPrice.shift(1)))
        com_after_cleaning += len(mkt_crsp.dropna(subset = "CompanyLogRet"))
        syn_after_cleaning += len(mkt_ivol.dropna(subset = "SynthLogRet"))

        com_reg = oes.regression(mkt_crsp,"Company")
        ivol_reg = oes.regression(mkt_ivol,"Synth")

        if type(ivol_reg) == str or type(com_reg) == str:
            print("Reg Error")
            raise Error

        com_after_regression += len(com_reg.dropna(subset = "Tstat"))
        syn_after_regression += len(ivol_reg.dropna(subset = "Tstat"))

        syn_df_reg = ivol_reg.rename(columns={"ResRtn":"SynResRtn","Tstat":"SynTstat","Sig":"SynSig","ExplainedReturn":"SynExp"}).drop(columns= "Mkt_Lnrtn")
        com_df_reg = com_reg.rename(columns={"ResRtn":"ComResRtn","Tstat":"ComTstat","Sig":"ComSig","ExplainedReturn":"ComExp"}).drop(columns = "CFACPR")
        summary = syn_df_reg.join(com_df_reg,how="right")
        summary.loc[:,"Equal"] = summary.SynSig == summary.ComSig                   #Checking if both, syn and common, Tstats are significant
        summary.loc[:,"Direction"] = (summary.SynTstat/summary.ComTstat) >= 0       #Checking if the direction of both Tstats are similar
        for i in summary.index:                                                   
            if summary.loc[i,"Equal"] == False:                                     #Redflag = True, if significance is not equal 
                summary.loc[i,"Redflag"] = 1
            
            elif summary.loc[i,"Equal"] == True and (summary.loc[i,"SynSig"]\
                == False or summary.loc[i,"ComSig"] == False):                      #Redflag = False, if significance is equal but both are not significant
                summary.loc[i,"Redflag"] = 0
            
            elif summary.loc[i,"Equal"] == True and \
                summary.loc[i,"Direction"] == False:                                #Redflag = True, if significance is equal (both significant) but are in opposite directions
                summary.loc[i,"Redflag"] = 1
            
            else:                                                                   #Redflag = False, if significance is equal and the direction is same
                summary.loc[i,"Redflag"] = 0

        summary.replace(True,1,inplace=True)
        summary.replace(False,0,inplace=True)

        summary.loc[:,"DIVAMT"] = mkt_crsp.DIVAMT
        summary.loc[:,"PERMCO"] = mkt_crsp.PERMCO
        summary.loc[:,"TICKER"] = mkt_crsp.TICKER
        summary = summary[['TICKER','PERMCO','PRC','SynthPrice','DIVAMT','SynthLogRet','CompanyLogRet','SynExp','ComExp','SynResRtn','ComResRtn','SynTstat', 'ComTstat','SynSig','ComSig','StdErr_Synth','StdErr_Company','Equal','Direction', 'Redflag']]
        print(summary.TICKER.unique()[0],": Done",len(summary.dropna(subset= "Equal")))

        summary_count += len(summary.dropna(subset= "Equal"))

        summary_path = f'{source}\\summary_{filt}'
        if not os.path.exists(summary_path):
            os.makedirs(f"{source}\\summary_{filt}")

        sum_path = f"{source}\\summary_{filt}\\{tic}_summary_{filt}.csv"
        summary.dropna(subset = "SynResRtn").to_csv(sum_path)
        return(summary)

# %%
tickers

# %%
syn_before_cleaning = 0
com_before_cleaning = 0
syn_after_cleaning = 0
com_after_cleaning = 0
syn_after_regression = 0
com_after_regression = 0
summary_count = 0
volume_filter = True
oi_filter = True
zero_price_filter = True
filter_9999 = True
filt = "all_final"
fred = oes.fred("C:\\OES\\001\\DGS1 1Yr Constant Mat Treasury.xlsx")
blr = oes.blr("C:\\OES\\001\\BB BLR Index.xlsx")
marketdata = oes.marketdata("C:\\OES\\001\\crsp_ind\\7_crsp.csv")
it = 0
for path_crsp in glob.glob("C:\\OES\\001\\crsp_ind\\*_crsp.csv"):
    it += 1
    raw_df = oes.import_crsp(path_crsp)
    tickers = raw_df.TICKER.unique().tolist()
    if len(tickers) > 1:
        print("multi ticker")
        continue
    tickers = tickers[0]
    mkt_crsp = pd.DataFrame(index = marketdata.index.tolist())
    mkt_ivol = pd.DataFrame(index = marketdata.index.tolist())
    print(it , raw_df.PERMCO.unique()[0])

    tic_ivol = oes.import_ivol(tickers,"C:\\OES\\ivol_ind\\")
    
    if len(tic_ivol) < 1:
        print(f"{tickers} ivol file unavailable")
        continue
    
    tic_com_df = oes.return_check(oes.dupe_check(raw_df.reset_index(drop = True),path_crsp),path_crsp).set_index("DataDate")
    
    com_before_cleaning += len(tic_com_df.dropna(subset = "RET"))
    cfacpr = tic_com_df.CFACPR
    tic_ivol_df = oes.synthetic_stock(tic_ivol,cfacpr,fred,blr,volume_filter,oi_filter,zero_price_filter)
    
    mkt_crsp.loc[tic_com_df.index,"PRC"] = tic_com_df.PRC
    mkt_crsp.loc[tic_com_df.index,"TICKER"] = tic_com_df.TICKER
    mkt_crsp.loc[tic_com_df.index,"RET"] = tic_com_df.RET
    mkt_crsp.loc[tic_com_df.index,"CFACPR"] = tic_com_df.CFACPR
    mkt_crsp.loc[tic_com_df.index,"PERMCO"] = tic_com_df.PERMCO
    mkt_crsp.loc[tic_com_df.index,"DIVAMT"] = tic_com_df.DIVAMT
    mkt_crsp.loc[tic_com_df.index,"Mkt_Lnrtn"] = marketdata.Mkt_Lnrtn
    
    mkt_ivol.loc[tic_com_df.index,"Mkt_Lnrtn"] = marketdata.Mkt_Lnrtn
    mkt_ivol.loc[tic_ivol_df.index,"CFACPR"] = tic_ivol_df.CFACPR
    mkt_ivol.loc[tic_ivol_df.index,"SynthPrice"] = tic_ivol_df.SynthPrice

    mkt_crsp.loc[:,"CompanyLogRet"] = ln(mkt_crsp.RET.astype(float) + 1)
    mkt_ivol.loc[:,"SynthLogRet"] = ln(((mkt_ivol.SynthPrice*(mkt_ivol.CFACPR.shift(1)/mkt_ivol.CFACPR))/mkt_ivol.SynthPrice.shift(1)))
    com_after_cleaning += len(mkt_crsp.dropna(subset = "CompanyLogRet"))
    syn_after_cleaning += len(mkt_ivol.dropna(subset = "SynthLogRet"))

    com_reg = oes.regression(mkt_crsp,"Company")
    if type(com_reg) == str:
        print("Reg Error - com")
        continue


    ivol_reg = oes.regression(mkt_ivol,"Synth")

    if type(ivol_reg) == str:
        print("Reg Error - ivol")
        continue

    com_after_regression += len(com_reg.dropna(subset = "Tstat"))
    syn_after_regression += len(ivol_reg.dropna(subset = "Tstat"))

    syn_df_reg = ivol_reg.rename(columns={"ResRtn":"SynResRtn","Tstat":"SynTstat","Sig":"SynSig","ExplainedReturn":"SynExp"}).drop(columns= "Mkt_Lnrtn")
    com_df_reg = com_reg.rename(columns={"ResRtn":"ComResRtn","Tstat":"ComTstat","Sig":"ComSig","ExplainedReturn":"ComExp"}).drop(columns = "CFACPR")
    summary = syn_df_reg.join(com_df_reg,how="right")
    summary.loc[:,"Equal"] = summary.SynSig == summary.ComSig                   #Checking if both, syn and common, Tstats are significant
    summary.loc[:,"Direction"] = (summary.SynTstat/summary.ComTstat) >= 0       #Checking if the direction of both Tstats are similar
    for i in summary.index:                                                   
        if summary.loc[i,"Equal"] == False:                                     #Redflag = True, if significance is not equal 
            summary.loc[i,"Redflag"] = 1
        
        elif summary.loc[i,"Equal"] == True and (summary.loc[i,"SynSig"]\
            == False or summary.loc[i,"ComSig"] == False):                      #Redflag = False, if significance is equal but both are not significant
            summary.loc[i,"Redflag"] = 0
        
        elif summary.loc[i,"Equal"] == True and \
            summary.loc[i,"Direction"] == False:                                #Redflag = True, if significance is equal (both significant) but are in opposite directions
            summary.loc[i,"Redflag"] = 1
        
        else:                                                                   #Redflag = False, if significance is equal and the direction is same
            summary.loc[i,"Redflag"] = 0

    summary.replace(True,1,inplace=True)
    summary.replace(False,0,inplace=True)

    summary.loc[:,"DIVAMT"] = mkt_crsp.DIVAMT
    summary.loc[:,"PERMCO"] = mkt_crsp.PERMCO
    summary.loc[:,"TICKER"] = mkt_crsp.TICKER
    summary = summary[['TICKER','PERMCO','PRC','SynthPrice','DIVAMT','SynthLogRet','CompanyLogRet','SynExp','ComExp','SynResRtn','ComResRtn','SynTstat', 'ComTstat','SynSig','ComSig','StdErr_Synth','StdErr_Company','Equal','Direction', 'Redflag']]
    print(summary.TICKER.unique()[0],": Done",len(summary.dropna(subset= "Equal")))

    summary_count += len(summary.dropna(subset= "Equal"))

    summary_path = f'{source}\\summary_{filt}'
    if not os.path.exists(summary_path):
        os.makedirs(f"{source}\\summary_{filt}")

    sum_path = f"{source}\\summary_{filt}\\{tickers}_summary_{filt}.csv"
    summary.dropna(subset = "SynResRtn").to_csv(sum_path)

counts = pd.DataFrame(index=['Common','Synth','Total'],data={"BeforeCleaning":[com_before_cleaning,syn_before_cleaning,nan],"AfterCleaning": [com_after_cleaning,syn_after_cleaning,nan],"AfterRegression":[com_after_regression,syn_after_regression,nan],"Total":[nan,nan,summary_count]})
counts.to_csv(f"{source}\\{filt}.csv")
# Out:
# 1 10020
# CSBR ivol file unavailable
# 2 10039
# HIFS ivol file unavailable
# 3 10042
# TORM ivol file unavailable
# 4 10053
# DRL ivol file unavailable
# 5 10059
# LWAY ivol file unavailable
# 6 10065
# Reg Error - ivol
# multi ticker
# 8 10104
# BTUI ivol file unavailable
# 9 10107
# Reg Error - ivol
# 10 10110
# Reg Error - ivol
# 11 10127
# CLRO ivol file unavailable
# 12 10147
# Reg Error - ivol
# 13 1015
# STZ : Done 1259
# 14 10171
# SPLS : Done 1008
# 15 10181
# ISDR ivol file unavailable
# 16 10210
# CRUS : Done 1259
# 17 10218
# Reg Error - ivol
# 18 10224
# SYMC : Done 1259
# 19 10241
# Reg Error - ivol
# 20 10256
# Reg Error - ivol
# 21 10288
# Reg Error - ivol
# 22 10299
# Reg Error - ivol
# 23 10302
# Reg Error - ivol
# 24 10303
# EA : Done 1259
# 25 10323
# Reg Error - ivol
# 26 1033
# Reg Error - ivol
# 27 10358
# Reg Error - ivol
# 28 10359
# Reg Error - ivol
# 29 1035
# COKE ivol file unavailable
# 30 10360
# Reg Error - ivol
# 31 10380
# Reg Error - ivol
# 32 10390
# BLFS ivol file unavailable
# multi ticker
# multi ticker
# 35 10419
# Reg Error - ivol
# 36 10421
# Reg Error - ivol
# 37 10467
# Reg Error - ivol
# 38 10486
# CSCO : Done 1259
# 39 10504
# Reg Error - ivol
# 40 10512
# Reg Error - ivol
# 41 10544
# Reg Error - ivol
# 42 10545
# Reg Error - ivol
# 43 10561
# Reg Error - ivol
# 44 10563
# Reg Error - ivol
# multi ticker
# 46 10566
# Reg Error - ivol
# 47 10567
# Reg Error - ivol
# 48 10593
# Reg Error - ivol
# 49 10594
# Reg Error - ivol
# 50 10634
# XLNX : Done 1259
# 51 10637
# ESBF ivol file unavailable
# 52 10651
# Reg Error - ivol
# 53 10652
# Reg Error - ivol
# multi ticker
# 55 10676
# GRF ivol file unavailable
# multi ticker
# 57 10690
# MOC ivol file unavailable
# 58 10691
# Reg Error - ivol
# 59 1071
# CDE : Done 1259
# 60 10724
# Reg Error - ivol
# 61 1072
# Reg Error - ivol
# 62 10743
# Reg Error - ivol
# 63 10758
# Reg Error - ivol
# 64 10759
# Reg Error - ivol
# 65 10805
# Reg Error - ivol
# 66 10815
# TBAC ivol file unavailable
# 67 10817
# Reg Error - ivol
# 68 10827
# Reg Error - ivol
# 69 10828
# Reg Error - ivol
# multi ticker
# 71 10833
# API ivol file unavailable
# 72 10843
# Reg Error - ivol
# 73 10855
# Reg Error - ivol
# 74 10860
# Reg Error - ivol
# 75 10867
# Reg Error - ivol
# 76 10876
# REGN : Done 1259
# 77 10877
# Reg Error - ivol
# 78 10883
# VIFL ivol file unavailable
# 79 10894
# Reg Error - ivol
# 80 10895
# Reg Error - ivol
# 81 10901
# Reg Error - ivol
# 82 10905
# Reg Error - ivol
# 83 10924
# Reg Error - ivol
# multi ticker
# 85 10954
# Reg Error - ivol
# 86 10959
# Reg Error - ivol
# 87 10962
# Reg Error - ivol
# 88 10968
# PNRA : Done 1008
# 89 10972
# Reg Error - ivol
# 90 10989
# Reg Error - ivol
# multi ticker
# 92 10993
# Reg Error - ivol
# 93 10996
# Reg Error - ivol
# 94 11001
# Reg Error - ivol
# 95 11003
# Reg Error - ivol
# multi ticker
# 97 1100
# CRD ivol file unavailable
# 98 11011
# Reg Error - ivol
# 99 11018
# Reg Error - ivol
# 100 11021
# NSAT ivol file unavailable
# 101 11023
# Reg Error - ivol
# 102 11029
# AEY ivol file unavailable
# 103 1103
# Reg Error - ivol
# 104 11042
# Reg Error - ivol
# 105 11050
# Reg Error - ivol
# 106 11052
# Reg Error - ivol
# 107 11064
# Reg Error - ivol
# multi ticker
# 109 11092
# Reg Error - ivol
# 110 11099
# Reg Error - ivol
# 111 11100
# Reg Error - ivol
# 112 11101
# NTN ivol file unavailable
# 113 11103
# Reg Error - ivol
# 114 11106
# Reg Error - ivol
# 115 11111
# Reg Error - ivol
# 116 11112
# BIIB : Done 1259
# 117 11123
# Reg Error - ivol
# 118 11148
# Reg Error - ivol
# 119 11157
# WTT ivol file unavailable
# 120 11161
# Reg Error - ivol
# 121 11186
# ARCI ivol file unavailable
# 122 11188
# Reg Error - ivol
# 123 11204
# Reg Error - ivol
# 124 11206
# BSTC ivol file unavailable
# 125 11208
# ARIS ivol file unavailable
# multi ticker
# 127 11225
# Reg Error - ivol
# 128 11235
# Reg Error - ivol
# 129 11238
# Reg Error - ivol
# 130 11247
# Reg Error - ivol
# 131 11248
# Reg Error - ivol
# 132 11253
# QCOM : Done 1259
# 133 11257
# Reg Error - ivol
# 134 11266
# PERF ivol file unavailable
# 135 11270
# Reg Error - ivol
# 136 11276
# Reg Error - ivol
# 137 11277
# Reg Error - ivol
# 138 11282
# AHPI ivol file unavailable
# 139 11291
# Reg Error - ivol
# 140 11300
# GILD : Done 1259
# 141 11304
# MSON ivol file unavailable
# 142 11309
# Reg Error - ivol
# 143 11310
# WFM : Done 1008
# 144 11316
# Reg Error - ivol
# 145 1131
# Reg Error - ivol
# 146 11324
# Reg Error - ivol
# 147 11335
# Reg Error - ivol
# 148 11342
# Reg Error - ivol
# 149 11344
# Reg Error - ivol
# 150 11358
# Reg Error - ivol
# 151 11361
# Reg Error - ivol
# 152 11371
# Reg Error - ivol
# 153 11383
# Reg Error - ivol
# 154 11401
# APTO ivol file unavailable
# 155 11403
# Reg Error - ivol
# 156 11405
# Reg Error - ivol
# 157 11412
# TWX : Done 1259
# 158 11413
# Reg Error - ivol
# 159 11415
# USAK ivol file unavailable
# 160 11431
# Reg Error - ivol
# multi ticker
# 162 11439
# Reg Error - ivol
# 163 11440
# Reg Error - ivol
# 164 11446
# Reg Error - ivol
# 165 11454
# Reg Error - ivol
# 166 11455
# Reg Error - ivol
# 167 11459
# HFFC ivol file unavailable
# 168 11469
# Reg Error - ivol
# multi ticker
# 170 11473
# Reg Error - ivol
# 171 11479
# Reg Error - ivol
# 172 11480
# Reg Error - ivol
# 173 11482
# Reg Error - ivol
# 174 11486
# Reg Error - ivol
# 175 11506
# Reg Error - ivol
# multi ticker
# 177 11515
# ADAT ivol file unavailable
# multi ticker
# 179 11530
# Reg Error - ivol
# 180 11542
# Reg Error - ivol
# 181 11544
# Reg Error - ivol
# 182 11545
# Reg Error - ivol
# 183 11547
# Reg Error - ivol
# 184 11558
# BBBY : Done 1259
# 185 11559
# DHI : Done 1259
# 186 11561
# Reg Error - ivol
# 187 11565
# Reg Error - ivol
# 188 11569
# ESRX : Done 1259
# 189 11576
# Reg Error - ivol
# 190 11591
# Reg Error - ivol
# 191 11592
# SBUX : Done 1259
# 192 11600
# STRS ivol file unavailable
# 193 11606
# Reg Error - ivol
# 194 11616
# CRVP ivol file unavailable
# multi ticker
# 196 11619
# ABCW ivol file unavailable
# 197 11621
# Reg Error - ivol
# 198 11645
# Reg Error - ivol
# 199 11677
# Reg Error - ivol
# 200 11679
# Reg Error - ivol
# 201 1167
# Reg Error - ivol
# 202 11691
# FUNC ivol file unavailable
# 203 11697
# ESMC ivol file unavailable
# 204 11699
# Reg Error - ivol
# 205 116
# Reg Error - ivol
# 206 11705
# Reg Error - ivol
# 207 11706
# Reg Error - ivol
# 208 11709
# Reg Error - ivol
# 209 11713
# Reg Error - ivol
# 210 11717
# CCU ivol file unavailable
# 211 11729
# Reg Error - ivol
# 212 11755
# Reg Error - ivol
# 213 11757
# Reg Error - ivol
# 214 11758
# Reg Error - ivol
# 215 11764
# Reg Error - ivol
# 216 11777
# Reg Error - ivol
# 217 11778
# Reg Error - ivol
# 218 1177
# CTO ivol file unavailable
# 219 11780
# Reg Error - ivol
# 220 11785
# BAMM ivol file unavailable
# 221 11786
# QCOR : Done 252
# multi ticker
# 223 11791
# Reg Error - ivol
# 224 11795
# Reg Error - ivol
# 225 11801
# Reg Error - ivol
# 226 11806
# Reg Error - ivol
# 227 11807
# Reg Error - ivol
# 228 11808
# Reg Error - ivol
# multi ticker
# 230 11828
# Reg Error - ivol
# 231 11830
# Reg Error - ivol
# 232 11834
# MRVC ivol file unavailable
# multi ticker
# 234 11855
# Reg Error - ivol
# 235 11857
# Reg Error - ivol
# 236 11860
# Reg Error - ivol
# 237 11862
# Reg Error - ivol
# 238 11865
# Reg Error - ivol
# 239 11867
# Reg Error - ivol
# multi ticker
# 241 11871
# Reg Error - ivol
# 242 11879
# Reg Error - ivol
# multi ticker
# 244 1191
# Reg Error - ivol
# 245 11923
# Reg Error - ivol
# 246 11934
# RCKY ivol file unavailable
# 247 11937
# CHK : Done 1259
# 248 11946
# CREE : Done 1259
# 249 1194
# Reg Error - ivol
# 250 11950
# Reg Error - ivol
# 251 11952
# Reg Error - ivol
# 252 11958
# Reg Error - ivol
# 253 11960
# Reg Error - ivol
# 254 11963
# IEC ivol file unavailable
# multi ticker
# 256 11980
# NATH ivol file unavailable
# 257 11981
# UBCP ivol file unavailable
# 258 12000
# Reg Error - ivol
# 259 12005
# Reg Error - ivol
# 260 12009
# Reg Error - ivol
# 261 12011
# INTU : Done 1259
# 262 12013
# Reg Error - ivol
# 263 12014
# Reg Error - ivol
# 264 12015
# Reg Error - ivol
# 265 12025
# Reg Error - ivol
# 266 12027
# MCHP : Done 1259
# 267 12032
# Reg Error - ivol
# 268 12036
# Reg Error - ivol
# 269 12037
# Reg Error - ivol
# 270 12038
# Reg Error - ivol
# 271 12040
# Reg Error - ivol
# 272 12044
# Reg Error - ivol
# 273 12058
# BANF ivol file unavailable
# 274 12064
# Reg Error - ivol
# 275 12074
# FOSL : Done 1259
# 276 12083
# Reg Error - ivol
# 277 12086
# Reg Error - ivol
# 278 12097
# ORLY : Done 1259
# 279 12108
# Reg Error - ivol
# 280 12119
# Reg Error - ivol
# 281 12139
# Reg Error - ivol
# 282 12146
# CWEI ivol file unavailable
# 283 12147
# Reg Error - ivol
# 284 12154
# Reg Error - ivol
# 285 12185
# Reg Error - ivol
# 286 12194
# Reg Error - ivol
# 287 12197
# Reg Error - ivol
# 288 12204
# Reg Error - ivol
# 289 12214
# Reg Error - ivol
# 290 12221
# WAYN ivol file unavailable
# 291 1222
# Reg Error - ivol
# 292 12240
# Reg Error - ivol
# 293 12289
# Reg Error - ivol
# 294 12304
# KTEC ivol file unavailable
# 295 12305
# Reg Error - ivol
# 296 12317
# Reg Error - ivol
# 297 12319
# LBIX ivol file unavailable
# 298 12339
# Reg Error - ivol
# 299 12345
# ATRM ivol file unavailable
# 300 12346
# FLL ivol file unavailable
# 301 12347
# Reg Error - ivol
# 302 12378
# WINA ivol file unavailable
# multi ticker
# multi ticker
# 305 12390
# Reg Error - ivol
# 306 1239
# DAIO ivol file unavailable
# 307 12407
# Reg Error - ivol
# 566 14340
# Reg Error - ivol
# 567 14348
# Reg Error - ivol
# 568 14355
# OVBC ivol file unavailable
# 569 14374
# Reg Error - ivol
# 570 14377
# IRIX ivol file unavailable
# 571 14382
# Reg Error - ivol
# 572 14385
# LPTH ivol file unavailable
# 573 14387
# Reg Error - ivol
# 574 14393
# Reg Error - ivol
# 575 14394
# ALXN : Done 1259
# 576 14398
# SGRP ivol file unavailable
# 577 14408
# Reg Error - ivol
# 578 1440
# COBR ivol file unavailable
# 579 14427
# Reg Error - ivol
# 580 14433
# Reg Error - ivol
# 581 14442
# Reg Error - ivol
# 582 14458
# Reg Error - ivol
# 583 14470
# Reg Error - ivol
# 584 14479
# Reg Error - ivol
# 585 14494
# Reg Error - ivol
# 586 14497
# BOSC ivol file unavailable
# 587 14498
# OCC ivol file unavailable
# 588 14506
# Reg Error - ivol
# 589 14518
# Reg Error - ivol
# 590 1451
# Reg Error - ivol
# 591 14521
# YHOO : Done 1008
# 592 14525
# JCTCF ivol file unavailable
# 593 14527
# Reg Error - ivol
# 594 14531
# Reg Error - ivol
# 595 14535
# Reg Error - ivol
# 596 14548
# Reg Error - ivol
# 597 14567
# Reg Error - ivol
# 598 14568
# Reg Error - ivol
# 599 14569
# RCG ivol file unavailable
# 600 14572
# Reg Error - ivol
# multi ticker
# 602 14582
# Reg Error - ivol
# multi ticker
# 604 14602
# Reg Error - ivol
# 605 14633
# PFBI ivol file unavailable
# 606 14641
# Reg Error - ivol
# multi ticker
# 608 14659
# Reg Error - ivol
# 609 14661
# Reg Error - ivol
# 610 14676
# Reg Error - ivol
# 611 1467
# Reg Error - ivol
# 612 14700
# Reg Error - ivol
# multi ticker
# 614 14702
# Reg Error - ivol
# multi ticker
# multi ticker
# 617 14722
# Reg Error - ivol
# 618 14724
# DAEG ivol file unavailable
# 619 14737
# Reg Error - ivol
# 620 14740
# ARDM ivol file unavailable
# 621 14744
# Reg Error - ivol
# 622 14750
# BVSN ivol file unavailable
# multi ticker
# 624 14754
# Reg Error - ivol
# 625 14762
# Reg Error - ivol
# 626 14775
# Reg Error - ivol
# 627 14776
# CHKP : Done 1259
# 628 14778
# PROV ivol file unavailable
# 629 1477
# EDUC ivol file unavailable
# 630 14781
# Reg Error - ivol
# 631 14795
# Reg Error - ivol
# 632 14801
# Reg Error - ivol
# 633 14828
# Reg Error - ivol
# 634 14838
# Reg Error - ivol
# 635 14845
# Reg Error - ivol
# 636 14858
# WHLM ivol file unavailable
# 637 14859
# Reg Error - ivol
# 638 14863
# Reg Error - ivol
# multi ticker
# 640 14873
# Reg Error - ivol
# 641 14888
# Reg Error - ivol
# 642 14889
# Reg Error - ivol
# 643 14905
# Reg Error - ivol
# 644 14915
# ETFC : Done 1259
# 645 14923
# Reg Error - ivol
# 646 14927
# Reg Error - ivol
# 647 14931
# Reg Error - ivol
# 648 14932
# IDSA ivol file unavailable
# 649 14938
# Reg Error - ivol
# 650 14958
# WLFC ivol file unavailable
# 651 14969
# OCN : Done 1259
# 652 14970
# PRLS ivol file unavailable
# multi ticker
# 5752 7902
# MNST : Done 1259
# 5753 7913
# Reg Error - ivol
# 5754 7914
# ARKR ivol file unavailable
# 5755 7922
# Reg Error - ivol
# 5756 7953
# Reg Error - ivol
# 5757 7975
# AEPI ivol file unavailable
# 5758 7976
# Reg Error - ivol
# 5759 7978
# DGSE ivol file unavailable
# 5760 7980
# Reg Error - ivol
# 5761 7992
# RMCF ivol file unavailable
# 5762 7999
# Reg Error - ivol
# 5763 7
# AAPL : Done 1259
# 5764 8028
# Reg Error - ivol
# 5765 8037
# Reg Error - ivol
# 5766 8045
# ORCL : Done 1259
# 5767 8048
# MSFT : Done 1259
# 5768 8087
# Reg Error - ivol
# 5769 8093
# EMC : Done 756
# 5770 8125
# Reg Error - ivol
# 5771 8135
# Reg Error - ivol
# 5772 8158
# ESBK ivol file unavailable
# 5773 8179
# Reg Error - ivol
# 5774 8185
# DLHC ivol file unavailable
# 5775 8186
# CLDX : Done 1259
# 5776 8187
# Reg Error - ivol
# multi ticker
# 5778 8220
# Reg Error - ivol
# 5779 8222
# CY : Done 1259
# 5780 8228
# Reg Error - ivol
# 5781 8237
# Reg Error - ivol
# 5782 8254
# Reg Error - ivol
# 5783 8268
# Reg Error - ivol
# 5784 8278
# DJCO ivol file unavailable
# 5785 8284
# Reg Error - ivol
# multi ticker
# 5787 8299
# Reg Error - ivol
# 5788 82
# Reg Error - ivol
# 5789 8314
# Reg Error - ivol
# 5790 8317
# Reg Error - ivol
# 5791 8340
# Reg Error - ivol
# multi ticker
# 5793 8372
# TOL : Done 1259
# 5794 8377
# Reg Error - ivol
# 5795 840
# Reg Error - ivol
# 5796 8418
# Reg Error - ivol
# 5797 8431
# TWMC ivol file unavailable
# 5798 8441
# Reg Error - ivol
# multi ticker
# 5800 8458
# Reg Error - ivol
# 5801 8461
# PDEX ivol file unavailable
# 5802 8476
# ADBE : Done 1259
# 5803 8508
# Reg Error - ivol
# 5804 8526
# Reg Error - ivol
# 5805 8534
# Reg Error - ivol
# 5806 8549
# Reg Error - ivol
# 5807 8551
# PTSI ivol file unavailable
# 5808 8563
# Reg Error - ivol
# 5809 8565
# CYAN ivol file unavailable
# 5810 8570
# Reg Error - ivol
# 5811 8586
# STLY ivol file unavailable
# 5812 8596
# Reg Error - ivol
# 5813 8598
# Reg Error - ivol
# 5814 8600
# Reg Error - ivol
# 5815 8646
# Reg Error - ivol
# 5816 8674
# Reg Error - ivol
# 5817 8677
# BKSC ivol file unavailable
# multi ticker
# 5819 8702
# Reg Error - ivol
# 5820 871
# Reg Error - ivol
# 5821 8721
# Reg Error - ivol
# 5822 8738
# Reg Error - ivol
# 5823 8741
# Reg Error - ivol
# 5824 8743
# Reg Error - ivol
# 5825 8762
# Reg Error - ivol
# 5826 8766
# Reg Error - ivol
# 5827 8778
# ITIC ivol file unavailable
# 5828 8780
# Reg Error - ivol
# 5829 8786
# CERN : Done 1259
# 5830 8788
# FFKT ivol file unavailable
# 5831 8810
# Reg Error - ivol
# 5832 8811
# Reg Error - ivol
# 5833 8820
# Reg Error - ivol
# 5915 9804
# WM : Done 1259
# 5916 9806
# FUND ivol file unavailable
# 5917 9847
# Reg Error - ivol
# 5918 9848
# Reg Error - ivol
# 5919 9849
# MGCD ivol file unavailable
# 5920 9857
# Reg Error - ivol
# 5921 9868
# Reg Error - ivol
# multi ticker
# 5923 9882
# Reg Error - ivol
# 5924 9898
# PWX ivol file unavailable
# 5925 9899
# Reg Error - ivol
# 5926 9914
# Reg Error - ivol
# 5927 9971
# Reg Error - ivol
# 5928 9977
# Reg Error - ivol
# 5929 9999
# Reg Error - ivol

# %%
final = pd.DataFrame()
for path in glob.glob("C:\\OES\\summary_all_final\\*_summary_all_final.csv"):
    df = pd.read_csv(path).drop(columns="Unnamed: 0")
    data = pd.DataFrame({"Ticker":str(df.TICKER.unique()).replace("[","").replace("]",""),\
        "PERMCO":df.PERMCO.unique(),\
            "Datapoints":len(df),\
                "ComSig%":(df.ComSig.sum()/len(df)),\
                    "SynSig%":(df.SynSig.sum()/len(df)),\
                        "Equal%":(df.Equal.sum()/len(df)),\
                            "Direction%":(df.Direction.sum()/len(df)),\
                                "RedFlag%":(df.Redflag.sum()/len(df))})
    final = pd.concat([final,data]).reset_index(drop=True)

final.to_csv("C:\\OES\\final.csv")

# %%
final
# Out:
#      Ticker   PERMCO  Datapoints   ComSig%   SynSig%    Equal%  Direction%  \
# 0     'AAL'  20010.0        1007  0.057597  0.058590  0.991063    0.972195
# 1    'AAPL'      7.0        1256  0.043790  0.045382  0.995223    0.973726
# 2    'ABBV'  54287.0        1007  0.053625  0.049652  0.980139    0.878848
# 3     'ABT'  20017.0        1257  0.052506  0.046937  0.983294    0.871122
# 4     'ABX'  20065.0        1258  0.053259  0.055644  0.992846    0.972973
# ..      ...      ...         ...       ...       ...       ...         ...
# 489  'YOKU'  53623.0         252  0.055556  0.063492  0.992063    0.964286
# 490   'YUM'  32093.0        1254  0.044657  0.047049  0.984848    0.886762
# 491    'YY'  54274.0         252  0.055556  0.051587  0.988095    0.960317
# 492  'ZIOP'  51213.0         504  0.049603  0.051587  0.978175    0.863095
# 493  'ZNGA'  53965.0         501  0.041916  0.043912  0.998004    0.960080
#
#      RedFlag%
# 0    0.008937
# 1    0.004777
# 2    0.019861
# 3    0.016706
# 4    0.007154
# ..        ...
# 489  0.007937
# 490  0.015152
# 491  0.011905
# 492  0.021825
# 493  0.001996
#
# [494 rows x 8 columns]

# %%
fred
# Out:
#        DataDate    fred
# 0    2000-10-17  0.0592
# 1    2000-10-18  0.0591
# 2    2000-10-19  0.0596
# 3    2000-10-20  0.0594
# 4    2000-10-23  0.0593
# ...         ...     ...
# 5562 2022-02-10  0.0114
# 5563 2022-02-11  0.0107
# 5564 2022-02-14  0.0113
# 5565 2022-02-15  0.0111
# 5566 2022-02-16  0.0109
#
# [5567 rows x 2 columns]

# %%
pd.DataFrame({"1-Year Treasury Rate":fred.set_index("DataDate").fred,"Broker Dealer Rate": blr.set_index("DataDate").blr,"Market Log Returns":marketdata.Mkt_Lnrtn}).to_csv("Exhibit_2.csv")
